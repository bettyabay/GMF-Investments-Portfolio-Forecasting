# %% [markdown]
# Importing modules

# %%
# Import necessary libraries 
import pandas as pd
import sys
import os
sys.path.append(os.path.join(os.path.abspath('..')))
import src.data_loader as data_loader
import src.eda as eda
import importlib
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')

# %%
# Reload the module
importlib.reload(data_loader)
importlib.reload(eda)
# Out:
# <module 'src.eda' from 'c:\\Users\\USER\\Desktop\\KAIM\\GMF-Investments-Portfolio-Forecasting\\src\\eda.py'>

# %%
# Import your StockDataLoader class and ExploratoryDataAnalysis class
from src.data_loader import StockDataLoader
from src.eda import ExploratoryDataAnalysis

# %%
# Set parameters for data loading
tickers = ['TSLA', 'BND', 'SPY']
start_date = '2015-01-01'
end_date =  '2024-10-31'

# %% [markdown]
# Load The Data

# %%
# Create an instance of StockDataLoader
data_loader = StockDataLoader(tickers, start_date, end_date)

# %%
# Load data
data_loader.load_data()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 29, in load_data
#     logging.info(f'Loading data for {ticker} from {self.start_date} to {self.end_date}')
# Message: 'Loading data for TSLA from 2015-01-01 to 2024-10-31'
# Arguments: ()
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 39, in load_data
#     logging.info(f'Data for {ticker} loaded successfully.')
# Message: 'Data for TSLA loaded successfully.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 29, in load_data
#     logging.info(f'Loading data for {ticker} from {self.start_date} to {self.end_date}')
# Message: 'Loading data for BND from 2015-01-01 to 2024-10-31'
# Arguments: ()
# [*********************100%***********************]  1 of 1 completed
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 39, in load_data
#     logging.info(f'Data for {ticker} loaded successfully.')
# Message: 'Data for BND loaded successfully.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 29, in load_data
#     logging.info(f'Loading data for {ticker} from {self.start_date} to {self.end_date}')
# Message: 'Loading data for SPY from 2015-01-01 to 2024-10-31'
# Arguments: ()
# [*********************100%***********************]  1 of 1 completed
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\901950284.py", line 2, in <module>
#     data_loader.load_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 39, in load_data
#     logging.info(f'Data for {ticker} loaded successfully.')
# Message: 'Data for SPY loaded successfully.'
# Arguments: ()

# %%
# Save loaded data to CSV
data_loader.save_data_to_csv()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\2863117992.py", line 2, in <module>
#     data_loader.save_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 73, in save_data_to_csv
#     logging.info(f'DataFrame for {ticker} before saving:')
# Message: 'DataFrame for SPY before saving:'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\2863117992.py", line 2, in <module>
#     data_loader.save_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 74, in save_data_to_csv
#     logging.info(df.head())
# Message:                   Open        High         Low       Close     Volume
# Date
# 2015-01-02  172.592911  173.811145  171.542718  173.391068  121465900
# 2015-01-05  169.475876  171.702279  169.165023  171.534251  169632600
# 2015-01-06  167.879669  170.316112  167.073115  169.786811  209151400
# 2015-01-07  169.971558  170.316024  168.770144  169.223821  125346700
# 2015-01-08  172.987778  173.206226  171.383093  171.399886  147217800
# Arguments: ()
# Current columns for SPY: ['SPY', 'SPY', 'SPY', 'SPY', 'SPY']
# Number of columns: 5
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\2863117992.py", line 2, in <module>
#     data_loader.save_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 78, in save_data_to_csv
#     logging.info(f'Data for {ticker} saved to {file_path}')
# Message: 'Data for SPY saved to ../data/raw\\SPY.csv'
# Arguments: ()
# Data for SPY:
# Head:
#                   Open        High         Low       Close     Volume
# Date
# 2015-01-02  172.592911  173.811145  171.542718  173.391068  121465900
# 2015-01-05  169.475876  171.702279  169.165023  171.534251  169632600
# 2015-01-06  167.879669  170.316112  167.073115  169.786811  209151400
# 2015-01-07  169.971558  170.316024  168.770144  169.223821  125346700
# 2015-01-08  172.987778  173.206226  171.383093  171.399886  147217800
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2474 entries, 2015-01-02 to 2024-10-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2474 non-null   float64
#  1   High    2474 non-null   float64
#  2   Low     2474 non-null   float64
#  3   Close   2474 non-null   float64
#  4   Volume  2474 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 116.0 KB
# None
# Shape:
# (2474, 5)

# %%
# Clean the data
preprocessed_data = data_loader.preprocessing_data()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 92, in preprocessing_data
#     logging.info(f'Checking missing values for {ticker}')
# Message: 'Checking missing values for TSLA'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 99, in preprocessing_data
#     logging.info(f'Missing values for {ticker}: {missing_values}')
# Message: 'Missing values for TSLA: TSLA    0\nTSLA    0\nTSLA    0\nTSLA    0\nTSLA    0\ndtype: int64'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 120, in preprocessing_data
#     logging.info("Data has been sorted in ascending order.")
# Message: 'Data has been sorted in ascending order.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 92, in preprocessing_data
#     logging.info(f'Checking missing values for {ticker}')
# Message: 'Checking missing values for BND'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 99, in preprocessing_data
#     logging.info(f'Missing values for {ticker}: {missing_values}')
# Message: 'Missing values for BND: BND    0\nBND    0\nBND    0\nBND    0\nBND    0\ndtype: int64'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 120, in preprocessing_data
#     logging.info("Data has been sorted in ascending order.")
# Message: 'Data has been sorted in ascending order.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 92, in preprocessing_data
#     logging.info(f'Checking missing values for {ticker}')
# Message: 'Checking missing values for SPY'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 99, in preprocessing_data
#     logging.info(f'Missing values for {ticker}: {missing_values}')
# Message: 'Missing values for SPY: Open      0\nHigh      0\nLow       0\nClose     0\nVolume    0\ndtype: int64'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 120, in preprocessing_data
#     logging.info("Data has been sorted in ascending order.")
# Message: 'Data has been sorted in ascending order.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\3265439995.py", line 2, in <module>
#     preprocessed_data = data_loader.preprocessing_data()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 124, in preprocessing_data
#     logging.info('Data cleaning completed.')
# Message: 'Data cleaning completed.'
# Arguments: ()

# %%
# Save preprocessed data
data_loader.save_preprocessed_data_to_csv()
# Out:
# Cleaned Data for TSLA:
# Head:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2474 entries, 2015-01-02 to 2024-10-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TSLA    2474 non-null   float64
#  1   TSLA    2474 non-null   float64
#  2   TSLA    2474 non-null   float64
#  3   TSLA    2474 non-null   float64
#  4   TSLA    2474 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 116.0 KB
# Shape:
# (2474, 5)
#
# Cleaned Data for BND:
# Head:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2474 entries, 2015-01-02 to 2024-10-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BND     2474 non-null   float64
#  1   BND     2474 non-null   float64
#  2   BND     2474 non-null   float64
#  3   BND     2474 non-null   float64
#  4   BND     2474 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 116.0 KB
# Shape:
# (2474, 5)
#
# Cleaned Data for SPY:
# Head:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2474 entries, 2015-01-02 to 2024-10-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2474 non-null   float64
#  1   High    2474 non-null   float64
#  2   Low     2474 non-null   float64
#  3   Close   2474 non-null   float64
#  4   Volume  2474 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 116.0 KB
# Shape:
# (2474, 5)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 136, in save_preprocessed_data_to_csv
#     logging.info(f'DataFrame for cleaned {ticker} before saving:')
# Message: 'DataFrame for cleaned TSLA before saving:'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 137, in save_preprocessed_data_to_csv
#     logging.info(df.head())
# Message:                  TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 141, in save_preprocessed_data_to_csv
#     logging.info(f'Cleaned data for {ticker} saved to {file_path}')
# Message: 'Cleaned data for TSLA saved to ../data/cleaned\\cleaned_TSLA.csv'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 136, in save_preprocessed_data_to_csv
#     logging.info(f'DataFrame for cleaned {ticker} before saving:')
# Message: 'DataFrame for cleaned BND before saving:'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 137, in save_preprocessed_data_to_csv
#     logging.info(df.head())
# Message:                   BND        BND        BND        BND      BND
# Date
# 2015-01-02  62.573112  62.603397  62.398980  62.406553  2218800
# 2015-01-05  62.754818  62.777530  62.610970  62.641254  5820100
# 2015-01-06  62.936558  63.125829  62.860850  62.860850  3887600
# 2015-01-07  62.974384  63.050092  62.875965  62.944100  2433400
# 2015-01-08  62.875992  62.921415  62.815424  62.921415  1873400
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 141, in save_preprocessed_data_to_csv
#     logging.info(f'Cleaned data for {ticker} saved to {file_path}')
# Message: 'Cleaned data for BND saved to ../data/cleaned\\cleaned_BND.csv'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 136, in save_preprocessed_data_to_csv
#     logging.info(f'DataFrame for cleaned {ticker} before saving:')
# Message: 'DataFrame for cleaned SPY before saving:'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 137, in save_preprocessed_data_to_csv
#     logging.info(df.head())
# Message:                   Open        High         Low       Close     Volume
# Date
# 2015-01-02  172.592911  173.811145  171.542718  173.391068  121465900
# 2015-01-05  169.475876  171.702279  169.165023  171.534251  169632600
# 2015-01-06  167.879669  170.316112  167.073115  169.786811  209151400
# 2015-01-07  169.971558  170.316024  168.770144  169.223821  125346700
# 2015-01-08  172.987778  173.206226  171.383093  171.399886  147217800
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: '  '
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1098, in emit
#     msg = self.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 942, in format
#     return fmt.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: '  '
# Call stack:
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 595, in run_forever
#     self._run_once()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1881, in _run_once
#     handle._run()
#   File "C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_6600\172456095.py", line 2, in <module>
#     data_loader.save_preprocessed_data_to_csv()
#   File "c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\data_loader.py", line 141, in save_preprocessed_data_to_csv
#     logging.info(f'Cleaned data for {ticker} saved to {file_path}')
# Message: 'Cleaned data for SPY saved to ../data/cleaned\\cleaned_SPY.csv'
# Arguments: ()

# %%
# Create an instance of ExploratoryDataAnalysis
eda = ExploratoryDataAnalysis(preprocessed_data)

# %%
# Visualize closing prices
eda.visualize_closing_price()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:228, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Visualize closing prices
# ----> 2 eda.visualize_closing_price()
#
# File c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\src\eda.py:33, in ExploratoryDataAnalysis.visualize_closing_price(self)
#      31 for ticker, df in self.data.items():
#      32     plt.figure(figsize=(12, 6))
# ---> 33     sns.lineplot(x=df.index, y=df['Close'].squeeze(), label='Close Price', linewidth=2.5)
#      34     plt.title(f'{ticker} Closing Price Over Time', fontsize=16, fontweight='bold')
#      35     plt.xlabel('Date', fontsize=14)
#
# File c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\USER\Desktop\KAIM\GMF-Investments-Portfolio-Forecasting\myenv11\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Close'
